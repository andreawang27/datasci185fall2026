# %% [markdown]
# This is a Jupyter notebook!!!
#
# # Big Text
#
# ## Slightly smaller text
#
# ### ### Smallest text

# %% [markdown]
# <font size = "15">
# This is size 15 font
#
# <font size = "20" color = "blue">
#
# Blue, size 20 text

# %% [markdown]
# # This is my first Jupyter notebook

# %%
print ("my name is Andrea Wang")
# Out:
# my name is Andrea Wang
